# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/avocado.csv")

df['Date'] = pd.to_datetime(df["Date"])

albany_df = df[ df["region"] == "Albany" ]
albany_df.set_index("Date", inplace=True)
albany_df["AveragePrice"].plot()

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
albany_df.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %%
albany_df.sort_index(inplace=True)
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# /Users/isaacsutor/dashpractice/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# /Users/isaacsutor/dashpractice/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df.head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
# 2015-01-11     8424.77     8036.04      388.73          0.0  conventional
#
#             year  region                          price25ma
# Date
# 2015-01-04  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-01-04  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-01-11  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)

# %%
albany_df.tail(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region                          price25ma
# Date
# 2018-03-18  conventional  2018  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-03-25  conventional  2018  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-03-25       organic  2018  Albany  AxesSubplot(0.125,0.2;0.775x0.68)

# %%
albany_df.dropna().head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
# 2015-01-11     8424.77     8036.04      388.73          0.0  conventional
# 2015-01-11      838.44      838.44        0.00          0.0       organic
# 2015-01-18    11921.05    11651.09      269.96          0.0  conventional
#
#             year  region                          price25ma
# Date
# 2015-01-04  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-01-04  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-01-11  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-01-11  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-01-18  2015  Albany  AxesSubplot(0.125,0.2;0.775x0.68)

# %%
albany_df = df.copy()[df["region"] == "Albany" ]
albany_df.set_index("Date", inplace=True)
albany_df.sort_index(inplace=True)
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()

# %%
df.values
# Out:
# array([[0, Timestamp('2015-12-27 00:00:00'), 1.33, ..., 'conventional',
#         2015, 'Albany'],
#        [1, Timestamp('2015-12-20 00:00:00'), 1.35, ..., 'conventional',
#         2015, 'Albany'],
#        [2, Timestamp('2015-12-13 00:00:00'), 0.93, ..., 'conventional',
#         2015, 'Albany'],
#        ...,
#        [9, Timestamp('2018-01-21 00:00:00'), 1.87, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [10, Timestamp('2018-01-14 00:00:00'), 1.93, ..., 'organic', 2018,
#         'WestTexNewMexico'],
#        [11, Timestamp('2018-01-07 00:00:00'), 1.62, ..., 'organic', 2018,
#         'WestTexNewMexico']], dtype=object)

# %%
list(set(df["region"].values.tolist()))
# Out:
# ['GrandRapids',
#  'California',
#  'BaltimoreWashington',
#  'Boise',
#  'SanFrancisco',
#  'West',
#  'NewOrleansMobile',
#  'Nashville',
#  'HartfordSpringfield',
#  'RaleighGreensboro',
#  'Houston',
#  'Atlanta',
#  'GreatLakes',
#  'StLouis',
#  'NewYork',
#  'Tampa',
#  'NorthernNewEngland',
#  'Midsouth',
#  'TotalUS',
#  'Boston',
#  'BuffaloRochester',
#  'Jacksonville',
#  'LosAngeles',
#  'Northeast',
#  'Pittsburgh',
#  'WestTexNewMexico',
#  'SouthCarolina',
#  'Southeast',
#  'SanDiego',
#  'Philadelphia',
#  'Detroit',
#  'Indianapolis',
#  'CincinnatiDayton',
#  'PhoenixTucson',
#  'Seattle',
#  'Orlando',
#  'RichmondNorfolk',
#  'Charlotte',
#  'Columbus',
#  'DallasFtWorth',
#  'Louisville',
#  'Roanoke',
#  'SouthCentral',
#  'MiamiFtLauderdale',
#  'Syracuse',
#  'Sacramento',
#  'Plains',
#  'HarrisburgScranton',
#  'Portland',
#  'Albany',
#  'LasVegas',
#  'Spokane',
#  'Denver',
#  'Chicago']

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique()[:16]:
    print(region)
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets!
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
df.tail(3)
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9 2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
graph_df.tail(3)
# Out:
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
#
#             Charlotte_price25ma  Chicago_price25ma  \
# Date
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
#
#             CincinnatiDayton_price25ma  Columbus_price25ma  \
# Date
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
#
#             DallasFtWorth_price25ma  Denver_price25ma  Detroit_price25ma  \
# Date
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
#
#             GrandRapids_price25ma  GreatLakes_price25ma
# Date
# 2018-03-25                 1.3164                1.2788
# 2018-03-25                 1.3264                1.2568
# 2018-03-25                 1.3264                1.2788

# %%
df = pd.read_csv("datasets/avocado.csv")
df = df.copy()[df['type']=='organic']
df['Date'] = pd.to_datetime(df["Date"])

# %%
df.sort_values(by="Date", ascending=True, inplace=True)
df.head()
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume       4046      4225  \
# 9489           51 2015-01-04          1.24     142349.77  107490.73  25711.96
# 11205          51 2015-01-04          1.39       4414.29      56.21   2760.82
# 9801           51 2015-01-04          1.42      22480.07    3199.35   6916.72
# 11309          51 2015-01-04          1.23      19089.36   17522.46    735.22
# 9957           51 2015-01-04          1.54      61615.10    3633.93  42963.06
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9489   2.93     9144.15     9144.15        0.00          0.0  organic  2015
# 11205  0.00     1597.26     1139.42      457.84          0.0  organic  2015
# 9801   7.56    12356.44     1076.67    11279.77          0.0  organic  2015
# 11309  2.87      828.81      828.81        0.00          0.0  organic  2015
# 9957   0.00    15018.11     9763.55     5254.56          0.0  organic  2015
#
#            region
# 9489   California
# 11205     Roanoke
# 9801       Denver
# 11309    SanDiego
# 9957   GreatLakes

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets! (so df rather than series)
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])

graph_df.tail()
# Out:
#             California_price25ma  Roanoke_price25ma  Denver_price25ma  \
# Date
# 2018-02-25                1.9128             1.6136            1.7084
# 2018-03-04                1.8876             1.5972            1.6880
# 2018-03-11                1.8636             1.5828            1.6708
# 2018-03-18                1.8516             1.5624            1.6700
# 2018-03-25                1.8364             1.5532            1.6568
#
#             SanDiego_price25ma  GreatLakes_price25ma  \
# Date
# 2018-02-25              2.0276                1.5656
# 2018-03-04              1.9988                1.5460
# 2018-03-11              1.9668                1.5248
# 2018-03-18              1.9476                1.5012
# 2018-03-25              1.9268                1.4912
#
#             RichmondNorfolk_price25ma  DallasFtWorth_price25ma  \
# Date
# 2018-02-25                     1.5244                   1.5708
# 2018-03-04                     1.5016                   1.5536
# 2018-03-11                     1.4920                   1.5340
# 2018-03-18                     1.4744                   1.5196
# 2018-03-25                     1.4672                   1.5100
#
#             SanFrancisco_price25ma  HarrisburgScranton_price25ma  \
# Date
# 2018-02-25                  1.9960                        1.5004
# 2018-03-04                  1.9968                        1.4972
# 2018-03-11                  2.0016                        1.4956
# 2018-03-18                  1.9936                        1.4956
# 2018-03-25                  1.9776                        1.4900
#
#             Pittsburgh_price25ma  ...  MiamiFtLauderdale_price25ma  \
# Date                              ...
# 2018-02-25                1.4004  ...                       1.7140
# 2018-03-04                1.3976  ...                       1.7068
# 2018-03-11                1.3968  ...                       1.6904
# 2018-03-18                1.3944  ...                       1.6692
# 2018-03-25                1.3936  ...                       1.6392
#
#             TotalUS_price25ma  Nashville_price25ma  Northeast_price25ma  \
# Date
# 2018-02-25             1.7144               1.7296               1.6940
# 2018-03-04             1.6940               1.7036               1.6860
# 2018-03-11             1.6748               1.6688               1.6868
# 2018-03-18             1.6588               1.6300               1.6852
# 2018-03-25             1.6428               1.6004               1.6804
#
#             Atlanta_price25ma  Tampa_price25ma  Midsouth_price25ma  \
# Date
# 2018-02-25             1.8660           1.7204              1.7252
# 2018-03-04             1.8288           1.7104              1.7084
# 2018-03-11             1.7844           1.6916              1.6924
# 2018-03-18             1.7412           1.6776              1.6768
# 2018-03-25             1.6936           1.6484              1.6592
#
#             BaltimoreWashington_price25ma  NorthernNewEngland_price25ma  \
# Date
# 2018-02-25                         1.5836                        1.6280
# 2018-03-04                         1.5772                        1.6224
# 2018-03-11                         1.5732                        1.6264
# 2018-03-18                         1.5684                        1.6284
# 2018-03-25                         1.5568                        1.6312
#
#             West_price25ma
# Date
# 2018-02-25          1.8620
# 2018-03-04          1.8220
# 2018-03-11          1.7912
# 2018-03-18          1.7644
# 2018-03-25          1.7304
#
# [5 rows x 54 columns]

# %%
graph_df.plot(figsize=(8,5), legend=False)
